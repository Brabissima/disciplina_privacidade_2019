# %%
import csv
import numpy as np
import pandas as pd

# %%
k = 2

df = pd.read_csv('salario.csv')
print(df)
# Out:
#        id            pais                      estado              cidade  \
# 0       1   United States                     Alabama              Mobile
# 1       2        Portugal                       Porto                Rego
# 2       3          Sweden                      Kalmar            Emmaboda
# 3       4          Sweden                 Västmanland                Sala
# 4       5          France                    Bretagne           Quimperlé
# 5       6   United States                        Ohio          Cincinnati
# 6       7          France            Poitou-Charentes               Niort
# 7       8          Mexico                  Tamaulipas           Del Valle
# 8       9   United States                    Oklahoma       Oklahoma City
# 9      10          France           Champagne-Ardenne               Reims
# 10     11   United States                     Florida           Melbourne
# 11     12          Sweden                    Värmland              Årjäng
# ...

# %%
def anonimity(k):    
    salario_2 = df.copy()
    print(df.loc[[1]])
# Out:
#    id      pais estado cidade genero        data   salario
# 1   2  Portugal  Porto   Rego   Male  29/11/2007  $7833.82
