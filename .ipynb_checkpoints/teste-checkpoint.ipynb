# %%
import pandas as pd
import numpy as np
import csv

# %%
salario_2 = pd.read_csv('salario.csv')

# %% [markdown]
# # União dos atributos de localidade

# %%
df = salario_2.copy() 
local = []
cidades = salario_2.cidade
estados = salario_2.estado
paises = salario_2.pais

for i in range(0,len(cidades)):
    local.append(str('{}, {}, {}'.format(cidades[i], estados[i], paises[i])))

# %%
pd.DataFrame(local)
df = df.drop("cidade",axis=1)
df = df.drop("estado",axis=1)
df = df.drop("pais",axis=1)

df['local'] = local

sequence = ['id', 'local', 'genero', 'data', 'salario']
df = df.reindex(columns=sequence)

df
# Out:
#        id                                          local  genero        data  \
# 0       1                 Mobile, Alabama, United States    Male  10/01/1987
# 1       2                          Rego, Porto, Portugal    Male  29/11/2007
# 2       3                       Emmaboda, Kalmar, Sweden    Male  23/06/1984
# 3       4                      Sala, Västmanland, Sweden  Female  04/11/1983
# 4       5                    Quimperlé, Bretagne, France  Female  18/11/1990
# 5       6                Cincinnati, Ohio, United States  Female  10/07/1981
# 6       7                Niort, Poitou-Charentes, France  Female  23/03/1989
# 7       8                  Del Valle, Tamaulipas, Mexico    Male  02/05/1990
# 8       9         Oklahoma City, Oklahoma, United States    Male  27/11/1992
# 9      10               Reims, Champagne-Ardenne, France  Female  19/01/2007
# 10     11              Melbourne, Florida, United States    Male  29/01/2007
# 11     12                       Årjäng, Värmland, Sweden    Male  25/03/1995
# 12     13                       Uppsala, Uppsala, Sweden  Female  15/01/1996
# 13     14              Katrineholm, Södermanland, Sweden  Female  31/10/2002
# 14     15             Frankfort, Kentucky, United States  Female  14/11/1980
# 15     16                      Älvsjö, Stockholm, Sweden  Female  05/05/1985
# 16     17                     Thompson, Manitoba, Canada    Male  30/04/2009
# 17     18                 Mobile, Alabama, United States  Female  06/05/1983
# 18     19                Morelos, Veracruz Llave, Mexico    Male  09/11/2004
# 19     20                        Avesta, Dalarna, Sweden  Female  04/05/2000
# 20     21                          Nybro, Kalmar, Sweden  Female  28/02/1996
# 21     22           Corpus Christi, Texas, United States    Male  06/01/1999
# 22     23            Church End, England, United Kingdom    Male  27/04/1992
# 23     24                 Rouen, Haute-Normandie, France    Male  20/09/2002
# 24     25               Nantes, Pays de la Loire, France  Female  21/11/1990
# 25     26              Kvissleby, Västernorrland, Sweden    Male  19/10/1981
# 26     27              Göteborg, Västra Götaland, Sweden    Male  01/12/2000
# 27     28             Santo Aleixo, Portalegre, Portugal    Male  25/10/1999
# 28     29                Besançon, Franche-Comté, France    Male  19/04/1994
# 29     30                 Gustavsberg, Stockholm, Sweden  Female  16/08/1999
# ..    ...                                            ...     ...         ...
# 970   971                      Limoges, Limousin, France    Male  13/02/1985
# 971   972       Neuilly-sur-Marne, Île-de-France, France  Female  27/08/2007
# 972   973                    Sangalhos, Aveiro, Portugal    Male  21/01/2006
# 993  $7202.18
# 994  $7831.28
# 995  $7782.63
# 996  $4772.43
# 997  $5004.78
# 998  $5362.26
# 999  $3737.37
#
# [1000 rows x 5 columns]

# %% [markdown]
# # Árvore de Localização

# %%
nivel0Local = df.local.unique().tolist()

# %%
lista_local = []
nivel1Local = df["local"].str.split(", ", n=2, expand=True)
estado = nivel1Local.iloc[:,1]
pais = nivel1Local.iloc[:,2]
for i in range(0, nivel1Local.shape[0]):
    lista_local.append(["*, "+estado[i]+", "+pais[i]])
    
nivel1Local = pd.DataFrame(lista_local)
nivel1Local = nivel1Local[0].unique().tolist()

# %%
nivel2Local = []
for i in range(0, pais.shape[0]):
    nivel2Local.append("*, *, "+pais[i])
    
nivel2Local = pd.DataFrame(nivel2Local)
nivel2Local = nivel2Local[0].unique().tolist()

# %%
nivel3Local = "*, *, *"

# %%
arvLocal = [nivel0Local, nivel1Local, nivel2Local, nivel3Local]

# %%
local = "*, *, *"

# %%
for i in range(0, len(arvLocal)):
    if(local in arvLocal[i]):
        print(i)
# Out:
# 3

# %% [markdown]
# # Árvore da Data

# %%
nivel0Data = df.data.unique().tolist()

# %%
lista_data = []
nivel1Data = df["data"].str.split("/", n=2, expand=True)
mes = nivel1Data.iloc[:,1]
ano = nivel1Data.iloc[:,2]
for i in range(0, nivel1Data.shape[0]):
    lista_data.append(["**/"+mes[i]+"/"+ano[i]])
    
nivel1Data = pd.DataFrame(lista_data)
nivel1Data = nivel1Data[0].unique().tolist()

# %%
nivel2Data = []
for i in range(0, ano.shape[0]):
    nivel2Data.append("**/**/"+ano[i])
    
nivel2Data = pd.DataFrame(nivel2Data)
nivel2Data = nivel2Data[0].unique().tolist()

# %%
nivel3Data = "**/**/****"

# %%
arvData = [nivel0Data, nivel1Data, nivel2Data, nivel3Data]

# %%
data = "**/**/1981"

# %%
for i in range(0, len(arvData)):
    if(data in arvData[i]):
        print(i)
# Out:
# 2

# %% [markdown]
# # Árvore do Gênero

# %%
nivel0Genero = df.genero.unique().tolist()

# %%
nivel1Genero = "*"

# %%
arvGenero = [nivel0Genero, nivel1Genero]

# %%
genero = "*"

# %%
for i in range(0, len(arvGenero)):
    if(genero in arvGenero[i]):
        print(i)
# Out:
# 1

# %% [markdown]
# # Função de Precisão

# %%
def precisao(N, D, h, HGV): #N: número de atributos, D: número de registros, h: lista com altura da árvore de cada atributo, HGV: lista com alturas máximas das hierarquias dos atributos
    somatorio = 0
    for i in range(0,N):
        somatorio += h[i]/HGV[i]
    #como o somatório interno não está sendo utilizado como índice, basta multiplicar o somatório por D
    resultado = 1 - ((D*somatório)/(D*N))
    return resultado

# %% [markdown]
# # Distância

# %%
def dist(reg1, reg2):
    genero1 = np.array(reg1[2])
    local1 = np.array(reg1[1].split(", "))
    data1 = np.array(reg1[3].split("/"))
    genero2 = np.array(reg2[2])
    local2 = np.array(reg2[1].split(", "))
    data2 = np.array(reg2[3].split("/"))
    distValor = 0
    if(genero1 != genero2):
        distValor = distValor + 1
    if(data1[2] != data2[2]):
        distValor = distValor + 3
    else:
        if(data1[1] != data2[1]):
            distValor = distValor + 2
        else:
            if(data1[0] != data2[0]):
                distValor = distValor + 1
    if(local1[2] != local2[2]):
        distValor = distValor + 3
    else:
        if(local1[1] != local2[1]):
            distValor = distValor + 2
        else:
            if(local1[0] != local2[0]):
                distValor = distValor + 1
    return ('distancia': distValor, 'indice': reg2[0])

# %% [markdown]
# # Clusterização dos grupos

# %%
def agrupa(df, k):
    grupos = []
    agrupado = []
    i = 0
    df = np.random.permutation(df)
    for registro1 in range(0, df.shape[0]-1):
        if(df[registro1, 0] not in agrupado):
            distancia = []
            for registro2 in range(registro1+1, df.shape[0]):
                if (df[registro2,0] not in agrupado):
                    distancia.append(dist(df[registro1], df[registro2]))
            dtype = [('distancia', int), ('id', int)]
            values = distancia
            distancia = np.array(values, dtype = dtype)
            distancia = np.sort(distancia, order='distancia')
            if((df.shape[0] - len(agrupado))>=k):
                cluster = [df[registro1,0]]
                for semelhante in range(0, k-1):
                    cluster.append(distancia[semelhante][1])
                    agrupado.append(distancia[semelhante][1])
                agrupado.append(df[registro1,0])
                grupos.append(cluster)
            else:
                restantes = [df[registro1]]
                for restante in range(0, len(distancia)):
                    restantes.append(df[distancia[restante][1]-1])
                print(restantes)
            #print(grupos[-1])
        
        #registroProximo  = np.argmin(distanciaValor)
        #print(distancia[0])
        #grupo.append(df[registroProximo,0])
        #print(df[registroProximo])
        #df = np.delete(df, registroProximo, axis=0)
        #print(df[i])
        
        #df = np.delete(df, i, axis=0)
        #i = 0
        #print(grupo)
        #print(np.min(distanciaValor))
        #print(distanciaTexto[registroProximo])
        #print(distancia)

# %%
agrupa(df, 16)
# Out:
# [array([870, 'Newtown, England, United Kingdom', 'Female', '13/06/1997',
#        '$3561.11'], dtype=object), array([989, 'Anchorage, Alaska, United States', 'Female', '31/03/1997',
#        '$4630.14'], dtype=object), array([764, 'Metz, Lorraine, France', 'Female', '15/10/2004', '$2463.52'],
#       dtype=object), array([16, 'Älvsjö, Stockholm, Sweden', 'Female', '05/05/1985',
#        '$4391.85'], dtype=object), array([540, 'Monte Francisco, Faro, Portugal', 'Female', '24/04/1991',
#        '$5189.45'], dtype=object), array([400, 'Lindavista, Oaxaca, Mexico', 'Female', '13/06/1990',
#        '$3556.11'], dtype=object), array([182, 'Tulsa, Oklahoma, United States', 'Male', '17/05/2004',
#        '$5946.05'], dtype=object), array([736, 'Askim, Västra Götaland, Sweden', 'Male', '29/01/1991',
#        '$4930.16'], dtype=object)]
# [array([944, 'Lyon, Rhône-Alpes, France', 'Female', '02/07/2004',
#        '$2671.01'], dtype=object), array([400, 'Lindavista, Oaxaca, Mexico', 'Female', '13/06/1990',
#        '$3556.11'], dtype=object), array([989, 'Anchorage, Alaska, United States', 'Female', '31/03/1997',
#        '$4630.14'], dtype=object), array([764, 'Metz, Lorraine, France', 'Female', '15/10/2004', '$2463.52'],
#       dtype=object), array([540, 'Monte Francisco, Faro, Portugal', 'Female', '24/04/1991',
#        '$5189.45'], dtype=object), array([182, 'Tulsa, Oklahoma, United States', 'Male', '17/05/2004',
#        '$5946.05'], dtype=object), array([736, 'Askim, Västra Götaland, Sweden', 'Male', '29/01/1991',
#        '$4930.16'], dtype=object)]
# [array([987, 'Habo, Jönköping, Sweden', 'Male', '02/12/1994', '$6525.63'],
#       dtype=object), array([182, 'Tulsa, Oklahoma, United States', 'Male', '17/05/2004',
#        '$5946.05'], dtype=object), array([540, 'Monte Francisco, Faro, Portugal', 'Female', '24/04/1991',
#        '$5189.45'], dtype=object), array([989, 'Anchorage, Alaska, United States', 'Female', '31/03/1997',
#        '$4630.14'], dtype=object), array([764, 'Metz, Lorraine, France', 'Female', '15/10/2004', '$2463.52'],
#       dtype=object), array([400, 'Lindavista, Oaxaca, Mexico', 'Female', '13/06/1990',
#        '$3556.11'], dtype=object)]
# [array([990, 'Cran-Gevrier, Rhône-Alpes, France', 'Female', '26/08/1996',
#        '$4630.99'], dtype=object), array([989, 'Anchorage, Alaska, United States', 'Female', '31/03/1997',
#        '$4630.14'], dtype=object), array([764, 'Metz, Lorraine, France', 'Female', '15/10/2004', '$2463.52'],
#       dtype=object), array([540, 'Monte Francisco, Faro, Portugal', 'Female', '24/04/1991',
#        '$5189.45'], dtype=object), array([182, 'Tulsa, Oklahoma, United States', 'Male', '17/05/2004',
#        '$5946.05'], dtype=object)]
# [array([961, 'Reston, Virginia, United States', 'Male', '17/10/1987',
#        '$7817.66'], dtype=object), array([989, 'Anchorage, Alaska, United States', 'Female', '31/03/1997',
#        '$4630.14'], dtype=object), array([764, 'Metz, Lorraine, France', 'Female', '15/10/2004', '$2463.52'],
#       dtype=object), array([540, 'Monte Francisco, Faro, Portugal', 'Female', '24/04/1991',
#        '$5189.45'], dtype=object)]
# [array([937, 'Cestas, Aquitaine, France', 'Female', '26/03/1995',
#        '$3531.22'], dtype=object), array([989, 'Anchorage, Alaska, United States', 'Female', '31/03/1997',
#        '$4630.14'], dtype=object), array([540, 'Monte Francisco, Faro, Portugal', 'Female', '24/04/1991',
#        '$5189.45'], dtype=object)]
# [array([986, 'Hallsberg, Örebro, Sweden', 'Female', '16/10/1985',
#        '$6173.77'], dtype=object), array([989, 'Anchorage, Alaska, United States', 'Female', '31/03/1997',
#        '$4630.14'], dtype=object)]
# [array([907, "Sophia Antipolis, Provence-Alpes-Côte d'Azur, France",
#        'Female', '10/09/1984', '$5814.99'], dtype=object)]

# %%
df = np.array(df)

# %%
df2
